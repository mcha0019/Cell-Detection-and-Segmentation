# %% [markdown]
# ![top.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Setup**
#
# Clone repo, install dependencies

# %%
# !git clone https://github.com/mcha0019/Cell-Detection-and-Segmentation
# %cd Cell-Detection-and-Segmentation
# %pip install -qr requirements.txt

# %matplotlib inline
import matplotlib

# %% [markdown]
# **Inference**
#
# 2 folders of sample images are included; sample_images and sample_images_2. Additional images can be found at the cell tracking website. Challenge datasets contain unseen images not used for training the method.
#
# http://celltrackingchallenge.net/2d-datasets/
#
# http://celltrackingchallenge.net/3d-datasets/

# %%
# !python detect.py --image_folder sample_images --show_bbox --show_mask --show_vis --save_vis --padding 0 --FoI 0
